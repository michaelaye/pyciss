# %%
import glob
folders = glob.glob('/usr/local/ringsdata/opus/N*')

# %%
len(folders)
# Out:
# 489

# %%
def process_folder(folder):
    import glob
    from pysis.exceptions import ProcessError
    from pyciss import pipeline as p
    done = glob.glob(folder+'/*.map.cal.cub')
    if done:
        return folder,True
    img_name = glob.glob(folder+'/*.LBL')
    try:
        map_name = p.calibrate_ciss(img_name[0])
    except ProcessError as e:
        print(e)
        return folder,False
    return folder,True

# %%
from IPython.parallel import Client
c = Client()

# %%
lbview = c.load_balanced_view()

# %%
results = lbview.map_async(process_folder, folders)

# %%
for result in results:
    print(result)
# Out:
# ('/usr/local/ringsdata/opus/N1654259120', True)
# ('/usr/local/ringsdata/opus/N1503230827', True)
# ('/usr/local/ringsdata/opus/N1656999274', True)
# ('/usr/local/ringsdata/opus/N1584974874', True)
# ('/usr/local/ringsdata/opus/N1467347249', True)
# ('/usr/local/ringsdata/opus/N1584975764', True)
# ('/usr/local/ringsdata/opus/N1595340745', True)
# ('/usr/local/ringsdata/opus/N1591681974', True)
# ('/usr/local/ringsdata/opus/N1628683046', True)
# ('/usr/local/ringsdata/opus/N1600368532', True)
# ('/usr/local/ringsdata/opus/N1584974518', True)
# ('/usr/local/ringsdata/opus/N1541717407', True)
# ('/usr/local/ringsdata/opus/N1601011075', True)
# ('/usr/local/ringsdata/opus/N1591064802', True)
# ('/usr/local/ringsdata/opus/N1585782139', True)
# ('/usr/local/ringsdata/opus/N1584974073', True)
# ('/usr/local/ringsdata/opus/N1503229987', True)
# ('/usr/local/ringsdata/opus/N1654254507', True)
# ('/usr/local/ringsdata/opus/N1541716180', True)
# ('/usr/local/ringsdata/opus/N1640502932', True)
# ...

# %%
resultsdf = pd.DataFrame.from_dict(results.result)

# %%
s = resultsdf[~resultsdf[1]][0]

# %%
pwd
# Out:
# '/home/klay6683/src/pyciss/notebooks'

# %%
s.to_csv('/home/klay6683/failed_smaller_than_1.5km_ring_images.txt')
