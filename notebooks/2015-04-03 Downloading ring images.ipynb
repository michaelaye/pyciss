# %%
cd ~/Dropbox/DDocuments/UVIS/straws/
# Out:
# /Users/klay6683/Dropbox/DDocuments/UVIS/straws

# %%
df = pd.read_table("coiss_ahires.015.list.txt", sep=' ', skipinitialspace=True, header=None)
df
# Out:
#               0      1       2       3       4       5       6        7    8   \
# 0    N1467345444  0.343   0.380  121960  122435   35400  106000  CL1/CL2   59
# 1    N1467345503  0.337   0.371  122663  123130   34800  107000  CL1/CL2   59
# 2    N1467345562  0.332   0.363  123351  123811   34200  107000  CL1/CL2   59
# 3    N1467345621  0.330   0.359  124213  124672   33800  108000  CL1/CL2   59
# 4    N1467345680  0.328   0.354  125047  125504   33400  109000  CL1/CL2   59
# 5    N1467345739  0.324   0.346  125796  126246   32800  110000  CL1/CL2   59
# 6    N1467345798  0.319   0.337  126535  126980   32200  110000  CL1/CL2   59
# 7    N1467345857  0.314   0.330  127277  127716   31600  111000  CL1/CL2   59
# 8    N1467345916  0.311   0.324  128057  128492   31100  112000  CL1/CL2   59
# 9    N1467345975  0.307   0.318  128799  129229   30600  113000  CL1/CL2   59
# 10   N1467346034  0.303   0.312  129501  129926   30100  114000  CL1/CL2   59
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 490 entries, 0 to 489
# Data columns (total 13 columns):
# 0     490 non-null object
# 1     490 non-null float64
# 2     490 non-null float64
# 3     490 non-null int64
# 4     490 non-null int64
# 5     490 non-null float64
# 6     490 non-null float64
# 7     490 non-null object
# 8     490 non-null int64
# 9     490 non-null int64
# 10    490 non-null int64
# 11    490 non-null float64
# 12    490 non-null object
# dtypes: float64(5), int64(5), object(3)
# memory usage: 53.6+ KB

# %% [markdown]
# # List of images done in Miodrag's email

# %%
l = ['N1467346388_2',
'N1467346447_2',
'N1503244044',
'N1560309735',
'N1560310339',
'N1591682340',
'N1601009710',
'N1628683587']

# %%
opus = opusapi.OPUS()

# %%
opus.get_between_resolutions(res1=0, res2=1.7)

# %%
len(opus.obsids)
# Out:
# 100

# %%
opus.unpack_json_response??

# %%
len(opus)

# %%
opus.get_filename('N1467345444')
# Out:
# [Raw:
#  Label:
#  http://pds-rings.seti.org/volumes/COISS_2xxx/COISS_2004/data/1466584989_1467427246/N1467345444_2.LBL
#  Image:
#  http://pds-rings.seti.org/volumes/COISS_2xxx/COISS_2004/data/1466584989_1467427246/N1467345444_2.IMG
#  Calibrated:
#  Label:
#  http://pds-rings.seti.org/derived/COISS_2xxx/COISS_2004/data/1466584989_1467427246/N1467345444_2_CALIB.LBL
#  Image:
#  http://pds-rings.seti.org/derived/COISS_2xxx/COISS_2004/data/1466584989_1467427246/N1467345444_2_CALIB.IMG]

# %%
opus.download_previews()
# Out:
# ('Downloading', 'N1467345444_2_med.jpg')

# %%
opus.show_images()
# Out:
# <img style='width: 256px; margin: 0px; float: left; border: 1px solid black;' src='http://pds-rings.seti.org/browse/COISS_2xxx/COISS_2004/data/1466584989_1467427246/N1467345444_2_small.jpg' />
