# %%
pd.read_fwf("/home/klay6683/rings/coiss_ahires.015.list.txt")
# Out:
#      N1467345444  0.343   0.380  121960  122435  3.54e+04  1.06e+05  CL1/CL2  \
# 0    N1467345503  0.337   0.371  122663  123130     34800    107000  CL1/CL2
# 1    N1467345562  0.332   0.363  123351  123811     34200    107000  CL1/CL2
# 2    N1467345621  0.330   0.359  124213  124672     33800    108000  CL1/CL2
# 3    N1467345680  0.328   0.354  125047  125504     33400    109000  CL1/CL2
# 4    N1467345739  0.324   0.346  125796  126246     32800    110000  CL1/CL2
# 5    N1467345798  0.319   0.337  126535  126980     32200    110000  CL1/CL2
# 6    N1467345857  0.314   0.330  127277  127716     31600    111000  CL1/CL2
# 7    N1467345916  0.311   0.324  128057  128492     31100    112000  CL1/CL2
# 8    N1467345975  0.307   0.318  128799  129229     30600    113000  CL1/CL2
# 9    N1467346034  0.303   0.312  129501  129926     30100    114000  CL1/CL2
# 10   N1467346093  0.299   0.305  130196  130615     29600    114000  CL1/CL2
# ...

# %% [markdown]
# # List of images done in Miodrag's email

# %%
l = ['N1467346388_2',
'N1467346447_2',
'N1503244044',
'N1560309735',
'N1560310339',
'N1591682340',
'N1601009710',
'N1628683587']

# %%
opu
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fc0074355a97> in <module>()
# ----> 1 opus = opusapi.OPUS()
#
# NameError: name 'opusapi' is not defined
